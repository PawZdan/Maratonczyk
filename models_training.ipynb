# %% [markdown]
# ## Ten notebook ma na celu wytrenowanie modelu regresji, używając pakietu Pycaret, który opiera się na popularnym pakiecie Scikitlearn. Dane dotyczą półmaratonów Wrocławskich, które odbyły się w latach 2023 oraz 2024. Naszym celem jest wytrenowanie modelu na podstawie konkretnych danych:
# - wiek zawodnika,
# - płeć,
# - tempo na 5km,
# - czas przebiegnięcia całego półmaratonu.
# Naszą wartością docelową jest czas przebiegnięcia całego półmaratonu.

# %% [markdown]
# ## W pierwszej kolejności pobieram dane z tzw. chmury - Digital Ocean

# %%
import boto3
import os
import pandas as pd
from dotenv import load_dotenv

load_dotenv()
s3 = boto3.client(
    "s3",
    # aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    # aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
    # Endpoint jest potrzebny dlatego że używamy chmury innej niż AWS 
    # endpoint_url=os.getenv("AWS_ENDPOINT_URL_S3"), 
    # Gdybyśmy używali AWS to musielibyśmy natomiast podać region
    #region_name='eu-central-1'
)
BUCKET_NAME = "pawelsbucket"

# %%
df2023 = pd.read_csv(f"s3://{BUCKET_NAME}/data/dane_maraton2023.csv")
df2024 = pd.read_csv(f"s3://{BUCKET_NAME}/data/dane_maraton2024.csv")

# %% [markdown]
# ## W danych, znajduje się rocznik zawodnika. Dla modelu wartości typu 1996 oraz 1980, będą bardzo podobne, gdzie w rzeczywistości zawodników dzieli wtedy 16 lat, co przy średniej wieku ok 42 lata dla obu półmaratonów, jest to wartość znacząca. Zmieńmy więc rocznik na wiek.

# %%
df2023['Wiek'] = 2023 - df2023['Rocznik']
df2024['Wiek'] = 2024 - df2024['Rocznik']

# %% [markdown]
# ## Dane z obu półmaratonów zostały połączone, aby model był możliwie dokładny oraz uniwersalny.

# %%
df = pd.concat([df2023, df2024], ignore_index=True)

# %% [markdown]
# ## W df pozostawiamy tylko te kolumny, na których będziemy trenować model tj.: płeć, tempo na 5m, czas oraz wiek

# %%
df = df[["Płeć","5 km Tempo","Czas", "Wiek"]]

# %%
df
# Out:
#       Płeć  5 km Tempo    Czas  Wiek
# 0        M    2.923333  3899.0  31.0
# 1        M    2.960000  3983.0  37.0
# 2        M    3.153333  4104.0  27.0
# 3        M    3.236667  4216.0  35.0
# 4        M    3.240000  4227.0  28.0
# ...    ...         ...     ...   ...
# 21952    K         NaN     NaN  42.0
# 21953    K         NaN     NaN  26.0
# 21954    M         NaN     NaN  29.0
# 21955    K         NaN     NaN  33.0
# 21956    M         NaN     NaN  36.0
#
# [21957 rows x 4 columns]

# %% [markdown]
# ## Pozbywamy się wartości brakujących

# %%
df.isna().sum()
# Out:
# Płeć            11
# 5 km Tempo    3546
# Czas          3507
# Wiek           485
# dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# ## Dla tak przygotowanych danych, wytrenujmy model

# %%
from pycaret.regression import setup, compare_models, tune_model, pull, save_model

# %%
exp = setup(data = df, target="Czas", session_id=123)
# Out:
# <style type="text/css">
# #T_7cf32_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7cf32">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7cf32_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7cf32_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cf32_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7cf32_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7cf32_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7cf32_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7cf32_row1_col1" class="data row1 col1" >Czas</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7cf32_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_7cf32_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7cf32_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_7cf32_row3_col1" class="data row3 col1" >(17927, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7cf32_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_7cf32_row4_col1" class="data row4 col1" >(17927, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7cf32_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_7cf32_row5_col1" class="data row5 col1" >(12548, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7cf32_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_7cf32_row6_col1" class="data row6 col1" >(5379, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7cf32_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_7cf32_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7cf32_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_7cf32_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7cf32_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_7cf32_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7cf32_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_7cf32_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7cf32_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_7cf32_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7cf32_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_7cf32_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7cf32_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_7cf32_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7cf32_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_7cf32_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7cf32_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_7cf32_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7cf32_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_7cf32_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7cf32_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_7cf32_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7cf32_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_7cf32_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7cf32_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_7cf32_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7cf32_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_7cf32_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7cf32_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_7cf32_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_7cf32_row21_col1" class="data row21 col1" >2442</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_813fc th {
#   text-align: left;
# }
# #T_813fc_row0_col0, #T_813fc_row0_col1, #T_813fc_row0_col6, #T_813fc_row1_col0, #T_813fc_row1_col1, #T_813fc_row1_col2, #T_813fc_row1_col3, #T_813fc_row1_col4, #T_813fc_row1_col5, #T_813fc_row1_col6, #T_813fc_row2_col0, #T_813fc_row2_col1, #T_813fc_row2_col2, #T_813fc_row2_col3, #T_813fc_row2_col4, #T_813fc_row2_col5, #T_813fc_row2_col6, #T_813fc_row3_col0, #T_813fc_row3_col1, #T_813fc_row3_col2, #T_813fc_row3_col3, #T_813fc_row3_col4, #T_813fc_row3_col5, #T_813fc_row3_col6, #T_813fc_row4_col0, #T_813fc_row4_col1, #T_813fc_row4_col2, #T_813fc_row4_col3, #T_813fc_row4_col4, #T_813fc_row4_col5, #T_813fc_row4_col6, #T_813fc_row5_col0, #T_813fc_row5_col1, #T_813fc_row5_col2, #T_813fc_row5_col3, #T_813fc_row5_col4, #T_813fc_row5_col5, #T_813fc_row5_col6, #T_813fc_row6_col0, #T_813fc_row6_col1, #T_813fc_row6_col2, #T_813fc_row6_col3, #T_813fc_row6_col4, #T_813fc_row6_col5, #T_813fc_row6_col6, #T_813fc_row7_col0, #T_813fc_row7_col1, #T_813fc_row7_col2, #T_813fc_row7_col3, #T_813fc_row7_col4, #T_813fc_row7_col5, #T_813fc_row7_col6, #T_813fc_row8_col0, #T_813fc_row8_col1, #T_813fc_row8_col2, #T_813fc_row8_col3, #T_813fc_row8_col4, #T_813fc_row8_col5, #T_813fc_row8_col6, #T_813fc_row9_col0, #T_813fc_row9_col2, #T_813fc_row9_col3, #T_813fc_row9_col4, #T_813fc_row9_col5, #T_813fc_row10_col0, #T_813fc_row10_col1, #T_813fc_row10_col2, #T_813fc_row10_col3, #T_813fc_row10_col4, #T_813fc_row10_col5, #T_813fc_row10_col6, #T_813fc_row11_col0, #T_813fc_row11_col1, #T_813fc_row11_col2, #T_813fc_row11_col3, #T_813fc_row11_col4, #T_813fc_row11_col5, #T_813fc_row11_col6, #T_813fc_row12_col0, #T_813fc_row12_col1, #T_813fc_row12_col2, #T_813fc_row12_col3, #T_813fc_row12_col4, #T_813fc_row12_col5, #T_813fc_row12_col6, #T_813fc_row13_col0, #T_813fc_row13_col1, #T_813fc_row13_col2, #T_813fc_row13_col3, #T_813fc_row13_col4, #T_813fc_row13_col5, #T_813fc_row13_col6, #T_813fc_row14_col0, #T_813fc_row14_col1, #T_813fc_row14_col2, #T_813fc_row14_col3, #T_813fc_row14_col4, #T_813fc_row14_col5, #T_813fc_row14_col6, #T_813fc_row15_col0, #T_813fc_row15_col1, #T_813fc_row15_col2, #T_813fc_row15_col3, #T_813fc_row15_col4, #T_813fc_row15_col5, #T_813fc_row15_col6, #T_813fc_row16_col0, #T_813fc_row16_col1, #T_813fc_row16_col2, #T_813fc_row16_col3, #T_813fc_row16_col4, #T_813fc_row16_col5, #T_813fc_row16_col6, #T_813fc_row17_col0, #T_813fc_row17_col1, #T_813fc_row17_col2, #T_813fc_row17_col3, #T_813fc_row17_col4, #T_813fc_row17_col5, #T_813fc_row17_col6 {
#   text-align: left;
# }
# #T_813fc_row0_col2, #T_813fc_row0_col3, #T_813fc_row0_col4, #T_813fc_row0_col5, #T_813fc_row9_col1, #T_813fc_row9_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_813fc_row0_col7, #T_813fc_row1_col7, #T_813fc_row2_col7, #T_813fc_row3_col7, #T_813fc_row4_col7, #T_813fc_row5_col7, #T_813fc_row6_col7, #T_813fc_row8_col7, #T_813fc_row9_col7, #T_813fc_row10_col7, #T_813fc_row11_col7, #T_813fc_row12_col7, #T_813fc_row13_col7, #T_813fc_row14_col7, #T_813fc_row15_col7, #T_813fc_row16_col7, #T_813fc_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_813fc_row7_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_813fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_813fc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_813fc_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_813fc_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_813fc_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_813fc_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_813fc_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_813fc_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_813fc_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_813fc_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_813fc_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_813fc_row0_col1" class="data row0 col1" >299.4187</td>
#       <td id="T_813fc_row0_col2" class="data row0 col2" >170713.4911</td>
#       <td id="T_813fc_row0_col3" class="data row0 col3" >412.7915</td>
#       <td id="T_813fc_row0_col4" class="data row0 col4" >0.8833</td>
#       <td id="T_813fc_row0_col5" class="data row0 col5" >0.0523</td>
#       <td id="T_813fc_row0_col6" class="data row0 col6" >0.0391</td>
#       <td id="T_813fc_row0_col7" class="data row0 col7" >0.0830</td>
#     </tr>
#     <tr>
#       <th id="T_813fc_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_813fc_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_813fc_row1_col1" class="data row1 col1" >302.5669</td>
#       <td id="T_813fc_row1_col2" class="data row1 col2" >174331.0170</td>
#       <td id="T_813fc_row1_col3" class="data row1 col3" >417.1370</td>
#       <td id="T_813fc_row1_col4" class="data row1 col4" >0.8808</td>
#       <td id="T_813fc_row1_col5" class="data row1 col5" >0.0528</td>
#       <td id="T_813fc_row1_col6" class="data row1 col6" >0.0396</td>
#       <td id="T_813fc_row1_col7" class="data row1 col7" >0.1270</td>
#     </tr>
#     <tr>
#       <th id="T_813fc_level0_row2" class="row_heading level0 row2" >lasso</th>
#       <td id="T_813fc_row2_col0" class="data row2 col0" >Lasso Regression</td>
#       <td id="T_813fc_row2_col1" class="data row2 col1" >300.9290</td>
#       <td id="T_813fc_row2_col2" class="data row2 col2" >177226.7584</td>
#       <td id="T_813fc_row2_col3" class="data row2 col3" >420.4153</td>
#       <td id="T_813fc_row2_col4" class="data row2 col4" >0.8790</td>
#       <td id="T_813fc_row2_col5" class="data row2 col5" >0.0526</td>
#       <td id="T_813fc_row2_col6" class="data row2 col6" >0.0393</td>
#       <td id="T_813fc_row2_col7" class="data row2 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_813fc_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_813fc_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_813fc_row3_col1" class="data row3 col1" >300.9323</td>
#       <td id="T_813fc_row3_col2" class="data row3 col2" >177228.9407</td>
#       <td id="T_813fc_row3_col3" class="data row3 col3" >420.4171</td>
#       <td id="T_813fc_row3_col4" class="data row3 col4" >0.8790</td>
#       <td id="T_813fc_row3_col5" class="data row3 col5" >0.0526</td>
#       <td id="T_813fc_row3_col6" class="data row3 col6" >0.0393</td>
#       <td id="T_813fc_row3_col7" class="data row3 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_813fc_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_813fc_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_813fc_row4_col1" class="data row4 col1" >300.9289</td>
#       <td id="T_813fc_row4_col2" class="data row4 col2" >177228.9696</td>
#       <td id="T_813fc_row4_col3" class="data row4 col3" >420.4169</td>
#       <td id="T_813fc_row4_col4" class="data row4 col4" >0.8790</td>
#       <td id="T_813fc_row4_col5" class="data row4 col5" >0.0526</td>
#       <td id="T_813fc_row4_col6" class="data row4 col6" >0.0393</td>
#       <td id="T_813fc_row4_col7" class="data row4 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_813fc_level0_row5" class="row_heading level0 row5" >llar</th>
#       <td id="T_813fc_row5_col0" class="data row5 col0" >Lasso Least Angle Regression</td>
#       <td id="T_813fc_row5_col1" class="data row5 col1" >300.9290</td>
#       <td id="T_813fc_row5_col2" class="data row5 col2" >177226.7678</td>
#       <td id="T_813fc_row5_col3" class="data row5 col3" >420.4153</td>
#       <td id="T_813fc_row5_col4" class="data row5 col4" >0.8790</td>
#       <td id="T_813fc_row5_col5" class="data row5 col5" >0.0526</td>
#       <td id="T_813fc_row5_col6" class="data row5 col6" >0.0393</td>
#       <td id="T_813fc_row5_col7" class="data row5 col7" >0.

# %% [markdown]
# ## Już dla tak przygotowanych danych, osiągnęliśmy satysfakcjonujące wyniki: R2 na poziomie 0.88 oraz MAE na poziomie 299. Dla R2 maksymalna wartość to 1, MAE to średni błąd bezwględny, wyrażony w takiej samej jednostce co wartość docelowa czyli sekundy. Sprawdźmy czy możemy dopracować model aby otrzymać lepsze wyniki.

# %%
dfcopy = df.copy()

# %% [markdown]
# ## Na kopi danych, pozbywam się wartości odstających

# %%
Q1 = dfcopy["Czas"].quantile(0.25)
Q3 = dfcopy["Czas"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

fake_no_outliers_df = dfcopy[~((dfcopy["Czas"] < lower_bound) | (dfcopy["Czas"] > upper_bound))]

# %%
exp2 = setup(data = df, target="Czas", session_id=123)
best2 = compare_models()
# Out:
# <style type="text/css">
# #T_8774e_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8774e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8774e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8774e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8774e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8774e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8774e_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8774e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8774e_row1_col1" class="data row1 col1" >Czas</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8774e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_8774e_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8774e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_8774e_row3_col1" class="data row3 col1" >(17927, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8774e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_8774e_row4_col1" class="data row4 col1" >(17927, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8774e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_8774e_row5_col1" class="data row5 col1" >(12548, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8774e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_8774e_row6_col1" class="data row6 col1" >(5379, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8774e_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_8774e_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8774e_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_8774e_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8774e_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_8774e_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8774e_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_8774e_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8774e_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_8774e_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8774e_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_8774e_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8774e_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_8774e_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8774e_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_8774e_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8774e_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_8774e_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8774e_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_8774e_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8774e_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_8774e_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8774e_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_8774e_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8774e_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_8774e_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_8774e_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_8774e_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_8774e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_8774e_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_8774e_row21_col1" class="data row21 col1" >5a1a</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d5220 th {
#   text-align: left;
# }
# #T_d5220_row0_col0, #T_d5220_row0_col1, #T_d5220_row0_col6, #T_d5220_row1_col0, #T_d5220_row1_col1, #T_d5220_row1_col2, #T_d5220_row1_col3, #T_d5220_row1_col4, #T_d5220_row1_col5, #T_d5220_row1_col6, #T_d5220_row2_col0, #T_d5220_row2_col1, #T_d5220_row2_col2, #T_d5220_row2_col3, #T_d5220_row2_col4, #T_d5220_row2_col5, #T_d5220_row2_col6, #T_d5220_row3_col0, #T_d5220_row3_col1, #T_d5220_row3_col2, #T_d5220_row3_col3, #T_d5220_row3_col4, #T_d5220_row3_col5, #T_d5220_row3_col6, #T_d5220_row4_col0, #T_d5220_row4_col1, #T_d5220_row4_col2, #T_d5220_row4_col3, #T_d5220_row4_col4, #T_d5220_row4_col5, #T_d5220_row4_col6, #T_d5220_row5_col0, #T_d5220_row5_col1, #T_d5220_row5_col2, #T_d5220_row5_col3, #T_d5220_row5_col4, #T_d5220_row5_col5, #T_d5220_row5_col6, #T_d5220_row6_col0, #T_d5220_row6_col1, #T_d5220_row6_col2, #T_d5220_row6_col3, #T_d5220_row6_col4, #T_d5220_row6_col5, #T_d5220_row6_col6, #T_d5220_row7_col0, #T_d5220_row7_col1, #T_d5220_row7_col2, #T_d5220_row7_col3, #T_d5220_row7_col4, #T_d5220_row7_col5, #T_d5220_row7_col6, #T_d5220_row8_col0, #T_d5220_row8_col1, #T_d5220_row8_col2, #T_d5220_row8_col3, #T_d5220_row8_col4, #T_d5220_row8_col5, #T_d5220_row8_col6, #T_d5220_row9_col0, #T_d5220_row9_col2, #T_d5220_row9_col3, #T_d5220_row9_col4, #T_d5220_row9_col5, #T_d5220_row10_col0, #T_d5220_row10_col1, #T_d5220_row10_col2, #T_d5220_row10_col3, #T_d5220_row10_col4, #T_d5220_row10_col5, #T_d5220_row10_col6, #T_d5220_row11_col0, #T_d5220_row11_col1, #T_d5220_row11_col2, #T_d5220_row11_col3, #T_d5220_row11_col4, #T_d5220_row11_col5, #T_d5220_row11_col6, #T_d5220_row12_col0, #T_d5220_row12_col1, #T_d5220_row12_col2, #T_d5220_row12_col3, #T_d5220_row12_col4, #T_d5220_row12_col5, #T_d5220_row12_col6, #T_d5220_row13_col0, #T_d5220_row13_col1, #T_d5220_row13_col2, #T_d5220_row13_col3, #T_d5220_row13_col4, #T_d5220_row13_col5, #T_d5220_row13_col6, #T_d5220_row14_col0, #T_d5220_row14_col1, #T_d5220_row14_col2, #T_d5220_row14_col3, #T_d5220_row14_col4, #T_d5220_row14_col5, #T_d5220_row14_col6, #T_d5220_row15_col0, #T_d5220_row15_col1, #T_d5220_row15_col2, #T_d5220_row15_col3, #T_d5220_row15_col4, #T_d5220_row15_col5, #T_d5220_row15_col6, #T_d5220_row16_col0, #T_d5220_row16_col1, #T_d5220_row16_col2, #T_d5220_row16_col3, #T_d5220_row16_col4, #T_d5220_row16_col5, #T_d5220_row16_col6, #T_d5220_row17_col0, #T_d5220_row17_col1, #T_d5220_row17_col2, #T_d5220_row17_col3, #T_d5220_row17_col4, #T_d5220_row17_col5, #T_d5220_row17_col6 {
#   text-align: left;
# }
# #T_d5220_row0_col2, #T_d5220_row0_col3, #T_d5220_row0_col4, #T_d5220_row0_col5, #T_d5220_row9_col1, #T_d5220_row9_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_
row5_col0" class="data row5 col0" >Lasso Least Angle Regression</td>
#       <td id="T_d5220_row5_col1" class="data row5 col1" >300.9290</td>
#       <td id="T_d5220_row5_col2" class="data row5 col2" >177226.7678</td>
#       <td id="T_d5220_row5_col3" class="data row5 col3" >420.4153</td>
#       <td id="T_d5220_row5_col4" class="data row5 col4" >0.8790</td>
#       <td id="T_d5220_row5_col5" class="data row5 col5" >0.0526</td>
#       <td id="T_d5220_row5_col6" class="data row5 col6" >0.0393</td>
#       <td id="T_d5220_row5_col7" class="data row5 col7" >0.

# %%
tuned_gbr1 = tune_model(best, optimize='R2')
# Out:
# <style type="text/css">
# #T_ce526_row10_col0, #T_ce526_row10_col1, #T_ce526_row10_col2, #T_ce526_row10_col3, #T_ce526_row10_col4, #T_ce526_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ce526">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce526_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_ce526_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_ce526_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_ce526_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_ce526_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_ce526_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce526_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce526_row0_col0" class="data row0 col0" >311.5047</td>
#       <td id="T_ce526_row0_col1" class="data row0 col1" >196493.1394</td>
#       <td id="T_ce526_row0_col2" class="data row0 col2" >443.2755</td>
#       <td id="T_ce526_row0_col3" class="data row0 col3" >0.8633</td>
#       <td id="T_ce526_row0_col4" class="data row0 col4" >0.0562</td>
#       <td id="T_ce526_row0_col5" class="data row0 col5" >0.0410</td>
#     </tr>
#     <tr>
#       <th id="T_ce526_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ce526_row1_col0" class="data row1 col0" >308.8866</td>
#       <td id="T_ce526_row1_col1" class="data row1 col1" >172634.7737</td>
#       <td id="T_ce526_row1_col2" class="data row1 col2" >415.4934</td>
#       <td id="T_ce526_row1_col3" class="data row1 col3" >0.8794</td>
#       <td id="T_ce526_row1_col4" class="data row1 col4" >0.0528</td>
#       <td id="T_ce526_row1_col5" class="data row1 col5" >0.0406</td>
#     </tr>
#     <tr>
#       <th id="T_ce526_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ce526_row2_col0" class="data row2 col0" >323.3367</td>
#       <td id="T_ce526_row2_col1" class="data row2 col1" >197275.8338</td>
#       <td id="T_ce526_row2_col2" class="data row2 col2" >444.1574</td>
#       <td id="T_ce526_row2_col3" class="data row2 col3" >0.8532</td>
#       <td id="T_ce526_row2_col4" class="data row2 col4" >0.0560</td>
#       <td id="T_ce526_row2_col5" class="data row2 col5" >0.0421</td>
#     </tr>
#     <tr>
#       <th id="T_ce526_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ce526_row3_col0" class="data row3 col0" >312.1908</td>
#       <td id="T_ce526_row3_col1" class="data row3 col1" >181615.9831</td>
#       <td id="T_ce526_row3_col2" class="data row3 col2" >426.1643</td>
#       <td id="T_ce526_row3_col3" class="data row3 col3" >0.8664</td>
#       <td id="T_ce526_row3_col4" class="data row3 col4" >0.0538</td>
#       <td id="T_ce526_row3_col5" class="data row3 col5" >0.0409</td>
#     </tr>
#     <tr>
#       <th id="T_ce526_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ce526_row4_col0" class="data row4 col0" >316.3259</td>
#       <td id="T_ce526_row4_col1" class="data row4 col1" >192065.9420</td>
#       <td id="T_ce526_row4_col2" class="data row4 col2" >438.2533</td>
#       <td id="T_ce526_row4_col3" class="data row4 col3" >0.8769</td>
#       <td id="T_ce526_row4_col4" class="data row4 col4" >0.0551</td>
#       <td id="T_ce526_row4_col5" class="data row4 col5" >0.0411</td>
#     </tr>
#     <tr>
#       <th id="T_ce526_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ce526_row5_col0" class="data row5 col0" >334.2168</td>
#       <td id="T_ce526_row5_col1" class="data row5 col1" >228089.8193</td>
#       <td id="T_ce526_row5_col2" class="data row5 col2" >477.5875</td>
#       <td id="T_ce526_row5_col3" class="data row5 col3" >0.8421</td>
#       <td id="T_ce526_row5_col4" class="data row5 col4" >0.0603</td>
#       <td id="T_ce526_row5_col5" class="data row5 col5" >0.0436</td>
#     </tr>
#     <tr>
#       <th id="T_ce526_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ce526_row6_col0" class="data row6 col0" >338.0277</td>
#       <td id="T_ce526_row6_col1" class="data row6 col1" >222818.1686</td>
#       <td id="T_ce526_row6_col2" class="data row6 col2" >472.0362</td>
#       <td id="T_ce526_row6_col3" class="data row6 col3" >0.8571</td>
#       <td id="T_ce526_row6_col4" class="data row6 col4" >0.0584</td>
#       <td id="T_ce526_row6_col5" class="data row6 col5" >0.0434</td>
#     </tr>
#     <tr>
#       <th id="T_ce526_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ce526_row7_col0" class="data row7 col0" >318.9876</td>
#       <td id="T_ce526_row7_col1" class="data row7 col1" >204283.9811</td>
#       <td id="T_ce526_row7_col2" class="data row7 col2" >451.9779</td>
#       <td id="T_ce526_row7_col3" class="data row7 col3" >0.8606</td>
#       <td id="T_ce526_row7_col4" class="data row7 col4" >0.0565</td>
#       <td id="T_ce526_row7_col5" class="data row7 col5" >0.0416</td>
#     </tr>
#     <tr>
#       <th id="T_ce526_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ce526_row8_col0" class="data row8 col0" >313.8711</td>
#       <td id="T_ce526_row8_col1" class="data row8 col1" >177113.5079</td>
#       <td id="T_ce526_row8_col2" class="data row8 col2" >420.8486</td>
#       <td id="T_ce526_row8_col3" class="data row8 col3" >0.8814</td>
#       <td id="T_ce526_row8_col4" class="data row8 col4" >0.0537</td>
#       <td id="T_ce526_row8_col5" class="data row8 col5" >0.0411</td>
#     </tr>
#     <tr>
#       <th id="T_ce526_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ce526_row9_col0" class="data row9 col0" >309.4343</td>
#       <td id="T_ce526_row9_col1" class="data row9 col1" >179973.7534</td>
#       <td id="T_ce526_row9_col2" class="data row9 col2" >424.2331</td>
#       <td id="T_ce526_row9_col3" class="data row9 col3" >0.8848</td>
#       <td id="T_ce526_row9_col4" class="data row9 col4" >0.0537</td>
#       <td id="T_ce526_row9_col5" class="data row9 col5" >0.0404</td>
#     </tr>
#     <tr>
#       <th id="T_ce526_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_ce526_row10_col0" class="data row10 col0" >318.6782</td>
#       <td id="T_ce526_row10_col1" class="data row10 col1" >195236.4902</td>
#       <td id="T_ce526_row10_col2" class="data row10 col2" >441.4027</td>
#       <td id="T_ce526_row10_col3" class="data row10 col3" >0.8665</td>
#       <td id="T_ce526_row10_col4" class="data row10 col4" >0.0557</td>
#       <td id="T_ce526_row10_col5" class="data row10 col5" >0.0416</td>
#     </tr>
#     <tr>
#       <th id="T_ce526_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_ce526_row11_col0" class="data row11 col0" >9.7013</td>
#       <td id="T_ce526_row11_col1" class="data row11 col1" >17875.9257</td>
#       <td id="T_ce526_row11_col2" class="data row11 col2" >20.0034</td>
#       <td id="T_ce526_row11_col3" class="data row11 col3" >0.0132</td>
#       <td id="T_ce526_row11_col4" class="data row11 col4" >0.0022</td>
#       <td id="T_ce526_row11_col5" class="data row11 col5" >0.0011</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
results1 = pull()

# %%
results1
# Out:
#            MAE          MSE      RMSE      R2   RMSLE    MAPE
# Fold
# 0     311.5047  196493.1394  443.2755  0.8633  0.0562  0.0410
# 1     308.8866  172634.7737  415.4934  0.8794  0.0528  0.0406
# 2     323.3367  197275.8338  444.1574  0.8532  0.0560  0.0421
# 3     312.1908  181615.9831  426.1643  0.8664  0.0538  0.0409
# 4     316.3259  192065.9420  438.2533  0.8769  0.0551  0.0411
# 5     334.2168  228089.8193  477.5875  0.8421  0.0603  0.0436
# 6     338.0277  222818.1686  472.0362  0.8571  0.0584  0.0434
td>
#     </tr>
#     <tr>
#       <th id="T_6a287_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6a287_row6_col0" class="data row6 col0" >338.0277</td>
#       <td id="T_6a287_row6_col1" class="data row6 col1" >222818.1686</td>
#       <td id="T_6a287_row6_col2" class="data row6 col2" >472.0362</td>
#       <td id="T_6a287_row6_col3" class="data row6 col3" >0.8571</td>
#       <td id="T_6a287_row6_col4" class="data row6 col4" >0.0584</td>
#       <td id="T_6a287_row6_col5" class="data row6 col5" >0.0434</td>
#     </tr>
#     <tr>
#       <th id="T_6a287_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6a287_row7_col0" class="data row7 col0" >318.9876</td>
#       <td id="T_6a287_row7_col1" class="data row7 col1" >204283.9811</td>
#       <td id="T_6a287_row7_col2" class="data row7 col2" >451.9779</td>
#       <td id="T_6a287_row7_col3" class="data row7 col3" >0.8606</td>
#       <td id="T_6a287_row7_col4" class="data row7 col4" >0.0565</td>
#       <td id="T_6a287_row7_col5" class="data row7 col5" >0.0416</td>
#     </tr>
#     <tr>
#       <th id="T_6a287_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6a287_row8_col0" class="data row8 col0" >313.8711</td>
#       <td id="T_6a287_row8_col1" class="data row8 col1" >177113.5079</td>
#       <td id="T_6a287_row8_col2" class="data row8 col2" >420.8486</td>
#       <td id="T_6a287_row8_col3" class="data row8 col3" >0.8814</td>
#       <td id="T_6a287_row8_col4" class="data row8 col4" >0.0537</td>
#       <td id="T_6a287_row8_col5" class="data row8 col5" >0.0411</td>
#     </tr>
#     <tr>
#       <th id="T_6a287_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6a287_row9_col0" class="data row9 col0" >309.4343</td>
#       <td id="T_6a287_row9_col1" class="data row9 col1" >179973.7534</td>
#       <td id="T_6a287_row9_col2" class="data row9 col2" >424.2331</td>
#       <td id="T_6a287_row9_col3" class="data row9 col3" >0.8848</td>
#       <td id="T_6a287_row9_col4" class="data row9 col4" >0.0537</td>
#       <td id="T_6a287_row9_col5" class="data row9 col5" >0.0404</td>
#     </tr>
#     <tr>
#       <th id="T_6a287_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6a287_row10_col0" class="data row10 col0" >318.6782</td>
#       <td id="T_6a287_row10_col1" class="data row10 col1" >195236.4902</td>
#       <td id="T_6a287_row10_col2" class="data row10 col2" >441.4027</td>
#       <td id="T_6a287_row10_col3" class="data row10 col3" >0.8665</td>
#       <td id="T_6a287_row10_col4" class="data row10 col4" >0.0557</td>
#       <td id="T_6a287_row10_col5" class="data row10 col5" >0.0416</td>
#     </tr>
#     <tr>
#       <th id="T_6a287_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6a287_row11_col0" class="data row11 col0" >9.7013</td>
#       <td id="T_6a287_row11_col1" class="data row11 col1" >17875.9257</td>
#       <td id="T_6a287_row11_col2" class="data row11 col2" >20.0034</td>
#       <td id="T_6a287_row11_col3" class="data row11 col3" >0.0132</td>
#       <td id="T_6a287_row11_col4" class="data row11 col4" >0.0022</td>
#       <td id="T_6a287_row11_col5" class="data row11 col5" >0.0011</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# ## Strojenie hiperparametrów obu modeli, dla danych z outliersami oraz bez nich nie poskutkowało lepszymi wynikami R2. W takim razie naszym pierwotnym modelem będzie model uzyskany na samym początku.

# %%
save_model(best, 'best_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['5 km Tempo', 'Wiek'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['Płeć'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('ordinal_encoding',
#                   TransformerWrapper(include=['Płeć'],
#                                      transformer=OrdinalEncoder(cols=['Płeć'],
#                                                                 handle_missing='return_nan',
#                                                                 mapping=[{'col': 'Płeć',
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': K      0
#  M      1
#  NaN   -1
#  dtype: int64}]))),
#                  ('clean_column_names',
#                   TransformerWrapper(transformer=CleanColumnNames())),
#                  ('trained_model', GradientBoostingRegressor(random_state=123))]),
#  'best_model.pkl')
